# %%
import pandas as pd

# %%
df1 = pd.read_csv('../data/concat_1.csv')
df2 = pd.read_csv('../data/concat_2.csv')
df3 = pd.read_csv('../data/concat_3.csv')

# %%
df2
# Out:
#     A   B   C   D
# 0  a4  b4  c4  d4
# 1  a5  b5  c5  d5
# 2  a6  b6  c6  d6
# 3  a7  b7  c7  d7

# %%
df1
# Out:
#     A   B   C   D
# 0  a0  b0  c0  d0
# 1  a1  b1  c1  d1
# 2  a2  b2  c2  d2
# 3  a3  b3  c3  d3

# %%
df1
# Out:
#     A   B   C   D
# 0  a0  b0  c0  d0
# 1  a1  b1  c1  d1
# 2  a2  b2  c2  d2
# 3  a3  b3  c3  d3

# %%
#concate the dataframes
row_concat = pd.concat([df1, df2, df3])
row_concat
# Out:
#      A    B    C    D
# 0   a0   b0   c0   d0
# 1   a1   b1   c1   d1
# 2   a2   b2   c2   d2
# 3   a3   b3   c3   d3
# 0   a4   b4   c4   d4
# 1   a5   b5   c5   d5
# 2   a6   b6   c6   d6
# 3   a7   b7   c7   d7
# 0   a8   b8   c8   d8
# 1   a9   b9   c9   d9
# 2  a10  b10  c10  d10
# 3  a11  b11  c11  d11

# %%
row_concat.loc[0] # 0'th index data 0,0,0
# Out:
#     A   B   C   D
# 0  a0  b0  c0  d0
# 0  a4  b4  c4  d4
# 0  a8  b8  c8  d8

# %%
row_concat.iloc[0]
# Out:
# A    a0
# B    b0
# C    c0
# D    d0
# Name: 0, dtype: object

# %%
row_concat.iloc[1]
# Out:
# A    a1
# B    b1
# C    c1
# D    d1
# Name: 1, dtype: object

# %%
row_concat.reset_index()
# Out:
#     index    A    B    C    D
# 0       0   a0   b0   c0   d0
# 1       1   a1   b1   c1   d1
# 2       2   a2   b2   c2   d2
# 3       3   a3   b3   c3   d3
# 4       0   a4   b4   c4   d4
# 5       1   a5   b5   c5   d5
# 6       2   a6   b6   c6   d6
# 7       3   a7   b7   c7   d7
# 8       0   a8   b8   c8   d8
# 9       1   a9   b9   c9   d9
# 10      2  a10  b10  c10  d10
# 11      3  a11  b11  c11  d11

# %%
new_row = pd.Series(['n1','n2','n3','n4'])

# %%
new_row
# Out:
# 0    n1
# 1    n2
# 2    n3
# 3    n4
# dtype: object

# %%
pd.concat([df1, new_row])
# Out:
#      A    B    C    D    0
# 0   a0   b0   c0   d0  NaN
# 1   a1   b1   c1   d1  NaN
# 2   a2   b2   c2   d2  NaN
# 3   a3   b3   c3   d3  NaN
# 0  NaN  NaN  NaN  NaN   n1
# 1  NaN  NaN  NaN  NaN   n2
# 2  NaN  NaN  NaN  NaN   n3
# 3  NaN  NaN  NaN  NaN   n4

# %%
new_row_2 = pd.DataFrame([['n1','n2','n3','n4']],columns=['A','B','D','C'])
#use double bracket for data

# %%
new_row_2
# Out:
#     A   B   D   C
# 0  n1  n2  n3  n4

# %%
pd.concat([df1, new_row_2])
# Out:
#     A   B   C   D
# 0  a0  b0  c0  d0
# 1  a1  b1  c1  d1
# 2  a2  b2  c2  d2
# 3  a3  b3  c3  d3
# 0  n1  n2  n4  n3

# %%
type(row_concat.iloc[0])
# Out:
# pandas.core.series.Series

# %%
new_row_3 = pd.DataFrame([['n1','n2','n3']], columns=['A','B','D'])

# %%
new_row_3
# Out:
#     A   B   D
# 0  n1  n2  n3

# %%
pd.concat([df1, new_row_3])
# Out:
#     A   B    C   D
# 0  a0  b0   c0  d0
# 1  a1  b1   c1  d1
# 2  a2  b2   c2  d2
# 3  a3  b3   c3  d3
# 0  n1  n2  NaN  n3

# %%
new_row_3 = pd.DataFrame([['n1','n2','n3','n4','n5']], columns=['A','B','D','E','Z'])

# %%
new_row_3
# Out:
#     A   B   D   E   Z
# 0  n1  n2  n3  n4  n5

# %%
pd.concat([df1, new_row_3])
# Out:
#     A   B    C   D    E    Z
# 0  a0  b0   c0  d0  NaN  NaN
# 1  a1  b1   c1  d1  NaN  NaN
# 2  a2  b2   c2  d2  NaN  NaN
# 3  a3  b3   c3  d3  NaN  NaN
# 0  n1  n2  NaN  n3   n4   n5

# %%
col_concat = pd.concat([df1, df2, df3], axis=1)

# %%
col_concat
# Out:
#     A   B   C   D   A   B   C   D    A    B    C    D
# 0  a0  b0  c0  d0  a4  b4  c4  d4   a8   b8   c8   d8
# 1  a1  b1  c1  d1  a5  b5  c5  d5   a9   b9   c9   d9
# 2  a2  b2  c2  d2  a6  b6  c6  d6  a10  b10  c10  d10
# 3  a3  b3  c3  d3  a7  b7  c7  d7  a11  b11  c11  d11

# %%
df1
# Out:
#     A   B   C   D
# 0  a0  b0  c0  d0
# 1  a1  b1  c1  d1
# 2  a2  b2  c2  d2
# 3  a3  b3  c3  d3

# %%
col_concat['A']
# Out:
#     A   A    A
# 0  a0  a4   a8
# 1  a1  a5   a9
# 2  a2  a6  a10
# 3  a3  a7  a11

# %%
col_concat['B']
# Out:
#     B   B    B
# 0  b0  b4   b8
# 1  b1  b5   b9
# 2  b2  b6  b10
# 3  b3  b7  b11

# %%
df1
# Out:
#     A   B   C   D
# 0  a0  b0  c0  d0
# 1  a1  b1  c1  d1
# 2  a2  b2  c2  d2
# 3  a3  b3  c3  d3

# %%
df1.columns = ['A','B','C','D'] #assigning the columns
df2.columns = ['A','D','E','F']

# %%
df1
# Out:
#     A   B   C   D
# 0  a0  b0  c0  d0
# 1  a1  b1  c1  d1
# 2  a2  b2  c2  d2
# 3  a3  b3  c3  d3

# %%
pd.concat([df1, df2])
# Out:
#     A    B    C   D    E    F
# 0  a0   b0   c0  d0  NaN  NaN
# 1  a1   b1   c1  d1  NaN  NaN
# 2  a2   b2   c2  d2  NaN  NaN
# 3  a3   b3   c3  d3  NaN  NaN
# 0  a4  NaN  NaN  b4   c4   d4
# 1  a5  NaN  NaN  b5   c5   d5
# 2  a6  NaN  NaN  b6   c6   d6
# 3  a7  NaN  NaN  b7   c7   d7

# %%
#Renaming the index
df1.index = [0, 2, 5, 7]

# %%
df1
# Out:
#     A   B   C   D
# 0  a0  b0  c0  d0
# 2  a1  b1  c1  d1
# 5  a2  b2  c2  d2
# 7  a3  b3  c3  d3

# %%
pd.concat([df1, df2], axis=1)
# Out:
#      A    B    C    D    A    D    E    F
# 0   a0   b0   c0   d0   a4   b4   c4   d4
# 1  NaN  NaN  NaN  NaN   a5   b5   c5   d5
# 2   a1   b1   c1   d1   a6   b6   c6   d6
# 3  NaN  NaN  NaN  NaN   a7   b7   c7   d7
# 5   a2   b2   c2   d2  NaN  NaN  NaN  NaN
# 7   a3   b3   c3   d3  NaN  NaN  NaN  NaN

# %%
person = pd.read_csv('../data/survey_person.csv')
site = pd.read_csv('../data/survey_site.csv')
survey = pd.read_csv('../data/survey_survey.csv')
visited = pd.read_csv('../data/survey_visited.csv')

# %%
person.head()
# Out:
#       ident   personal    family
# 0      dyer    William      Dyer
# 1        pb      Frank   Pabodie
# 2      lake   Anderson      Lake
# 3       roe  Valentina   Roerich
# 4  danforth      Frank  Danforth

# %%
site.head()
# Out:
#     name    lat    long
# 0   DR-1 -49.85 -128.57
# 1   DR-3 -47.15 -126.72
# 2  MSK-4 -48.87 -123.40

# %%
survey.head()
# Out:
#    taken person quant  reading
# 0    619   dyer   rad     9.82
# 1    619   dyer   sal     0.13
# 2    622   dyer   rad     7.80
# 3    622   dyer   sal     0.09
# 4    734     pb   rad     8.41

# %%
visited.head()
# Out:
#    ident  site       dated
# 0    619  DR-1  1927-02-08
# 1    622  DR-1  1927-02-10
# 2    734  DR-3  1939-01-07
# 3    735  DR-3  1930-01-12
# 4    751  DR-3  1930-02-26

# %%
visited_subset = visited.iloc[[0, 2, 6],:]

# %%
visited_subset
# Out:
#    ident   site       dated
# 0    619   DR-1  1927-02-08
# 2    734   DR-3  1939-01-07
# 6    837  MSK-4  1932-01-14

# %%
#one to one merge
o2o = pd.merge(site, visited_subset,
              left_on='name', right_on='site')

# %%
o2o #Here on the site the key is 'name' and on the visited_subset the key is 'site'
# Out:
#     name    lat    long  ident   site       dated
# 0   DR-1 -49.85 -128.57    619   DR-1  1927-02-08
# 1   DR-3 -47.15 -126.72    734   DR-3  1939-01-07
# 2  MSK-4 -48.87 -123.40    837  MSK-4  1932-01-14

# %%
#Many to one merge
m2o = site.merge(visited_subset, left_on='name', right_on='site')
m2o
# Out:
#     name    lat    long  ident   site       dated
# 0   DR-1 -49.85 -128.57    619   DR-1  1927-02-08
# 1   DR-3 -47.15 -126.72    734   DR-3  1939-01-07
# 2  MSK-4 -48.87 -123.40    837  MSK-4  1932-01-14

# %%
df1 = pd.DataFrame({
                'a' : [1, 1, 1, 2 ,2],
                'b' : [10, 20, 30, 40, 50]
            })
df2 = pd.DataFrame({
            'a1' : [1, 1, 2, 2, 3],
            'b1' : [100, 200, 300, 400, 500]
            })

# %%
df1
# Out:
#    a   b
# 0  1  10
# 1  1  20
# 2  1  30
# 3  2  40
# 4  2  50

# %%
df2
# Out:
#    a1   b1
# 0   1  100
# 1   1  200
# 2   2  300
# 3   2  400
# 4   3  500

# %%
df1.merge(df2, left_on='a', right_on='a1')
# Out:
#    a   b  a1   b1
# 0  1  10   1  100
# 1  1  10   1  200
# 2  1  20   1  100
# 3  1  20   1  200
# 4  1  30   1  100
# 5  1  30   1  200
# 6  2  40   2  300
# 7  2  40   2  400
# 8  2  50   2  300
# 9  2  50   2  400
